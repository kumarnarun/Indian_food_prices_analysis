# %%
import pandas as pd

# %%
df = pd.read_csv('india-food-prices-1.csv')
df.head()
# Out:
# C:\Users\U6049975\AppData\Local\Temp\ipykernel_7012\3148324820.py:1: DtypeWarning: Columns (4,5,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('india-food-prices-1.csv')
#          date      admin1      admin2            market   latitude  longitude  \
# 0       #date  #adm1+name  #adm2+name  #loc+market+name   #geo+lat   #geo+lon
# 1  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 2  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 3  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 4  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
#
#              category      commodity        unit         pricetype   currency  \
# 0          #item+type     #item+name  #item+unit  #item+price+type  #currency
# 1  cereals and tubers           Rice          KG            actual        INR
# ...

# %%
df.dtypes
# Out:
# date         object
# admin1       object
# admin2       object
# market       object
# latitude     object
# longitude    object
# category     object
# commodity    object
# unit         object
# pricetype    object
# currency     object
# price        object
# usdprice     object
# dtype: object

# %%
df.infer_objects().dtypes
# Out:
# date         object
# admin1       object
# admin2       object
# market       object
# latitude     object
# longitude    object
# category     object
# commodity    object
# unit         object
# pricetype    object
# currency     object
# price        object
# usdprice     object
# dtype: object

# %%
df.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'unit', 'pricetype', 'currency', 'price',
#        'usdprice'],
#       dtype='object')

# %%
df1 = df.copy()
df1.head()
# Out:
#          date      admin1      admin2            market   latitude  longitude  \
# 0       #date  #adm1+name  #adm2+name  #loc+market+name   #geo+lat   #geo+lon
# 1  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 2  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 3  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 4  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
#
#              category      commodity        unit         pricetype   currency  \
# 0          #item+type     #item+name  #item+unit  #item+price+type  #currency
# 1  cereals and tubers           Rice          KG            actual        INR
# 2  cereals and tubers          Wheat          KG            actual        INR
# 3  miscellaneous food          Sugar          KG            actual        INR
# 4        oil and fats  Oil (mustard)          KG            actual        INR
#
#     price    usdprice
# ...

# %%
df1.drop(index=0, inplace = True)

# %%
df1.head()
# Out:
#          date   admin1     admin2     market   latitude  longitude  \
# 1  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 2  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 3  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 4  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#              category      commodity unit pricetype currency price usdprice
# 1  cereals and tubers           Rice   KG    actual      INR   8.0     0.25
# 2  cereals and tubers          Wheat   KG    actual      INR   5.0     0.16
# 3  miscellaneous food          Sugar   KG    actual      INR  13.5     0.43
# 4        oil and fats  Oil (mustard)   KG    actual      INR  31.0     0.99
# 5  cereals and tubers           Rice   KG    actual      INR   6.8     0.22

# %%
df1.shape
# Out:
# (133137, 13)

# %%
df1.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'unit', 'pricetype', 'currency', 'price',
#        'usdprice'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# date         object
# admin1       object
# admin2       object
# market       object
# latitude     object
# longitude    object
# category     object
# commodity    object
# unit         object
# pricetype    object
# currency     object
# price        object
# usdprice     object
# dtype: object

# %%
df1.describe()
# Out:
#               date         admin1       admin2  market latitude  longitude  \
# count       133137         132348       132348  133137   132348     132348
# unique         331             31          149     156      209        205
# top     2021-06-15  Uttar Pradesh  Mumbai city  Mumbai   18.975  72.825833
# freq          2941           9661         4112    4112     2920       2920
#
#                   category commodity    unit pricetype currency   price  \
# count               133137    133137  133137    133137   133137  133137
# unique                   6        23       3         1        1   23994
# top     cereals and tubers      Rice      KG    actual      INR    16.0
# freq                 33234     10573  123716    133137   133137    1393
#
#        usdprice
# count    133137
# unique     2873
# top        0.27
# freq       1241

# %%
df1.head()
# Out:
#          date   admin1     admin2     market   latitude  longitude  \
# 1  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 2  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 3  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 4  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#              category      commodity unit pricetype currency price usdprice
# 1  cereals and tubers           Rice   KG    actual      INR   8.0     0.25
# 2  cereals and tubers          Wheat   KG    actual      INR   5.0     0.16
# 3  miscellaneous food          Sugar   KG    actual      INR  13.5     0.43
# 4        oil and fats  Oil (mustard)   KG    actual      INR  31.0     0.99
# 5  cereals and tubers           Rice   KG    actual      INR   6.8     0.22

# %%
df1.loc[1:5:2]
# Out:
#          date   admin1     admin2     market   latitude  longitude  \
# 1  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 3  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#              category commodity unit pricetype currency price usdprice
# 1  cereals and tubers      Rice   KG    actual      INR   8.0     0.25
# 3  miscellaneous food     Sugar   KG    actual      INR  13.5     0.43
# 5  cereals and tubers      Rice   KG    actual      INR   6.8     0.22

# %%
df1.iloc[0:5:2]
# Out:
#          date   admin1     admin2     market   latitude  longitude  \
# 1  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 3  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#              category commodity unit pricetype currency price usdprice
# 1  cereals and tubers      Rice   KG    actual      INR   8.0     0.25
# 3  miscellaneous food     Sugar   KG    actual      INR  13.5     0.43
# 5  cereals and tubers      Rice   KG    actual      INR   6.8     0.22

# %%
df1.empty
# Out:
# False

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#          date      admin1      admin2            market   latitude  longitude  \
# 0       #date  #adm1+name  #adm2+name  #loc+market+name   #geo+lat   #geo+lon
# 1  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 2  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 3  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
# 4  1994-01-15       Delhi       Delhi             Delhi  28.666667  77.216667
#
#              category      commodity        unit         pricetype   currency  \
# 0          #item+type     #item+name  #item+unit  #item+price+type  #currency
# 1  cereals and tubers           Rice          KG            actual        INR
# 2  cereals and tubers          Wheat          KG            actual        INR
# 3  miscellaneous food          Sugar          KG            actual        INR
# 4        oil and fats  Oil (mustard)          KG            actual        INR
#
#     price    usdprice
# ...

# %%
df2.drop(index=0, inplace = True)

# %%
df2.set_index('date', inplace = True)

# %%
df2.head()
# Out:
#              admin1     admin2     market   latitude  longitude  \
# date
# 1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#                       category      commodity unit pricetype currency price  \
# date
# 1994-01-15  cereals and tubers           Rice   KG    actual      INR   8.0
# 1994-01-15  cereals and tubers          Wheat   KG    actual      INR   5.0
# 1994-01-15  miscellaneous food          Sugar   KG    actual      INR  13.5
# 1994-01-15        oil and fats  Oil (mustard)   KG    actual      INR  31.0
# 1994-01-15  cereals and tubers           Rice   KG    actual      INR   6.8
#
#            usdprice
# date
# 1994-01-15     0.25
# 1994-01-15     0.16
# 1994-01-15     0.43
# ...

# %%
df2.filter(regex='^2021', axis=0)
# Out:
#                          admin1           admin2      market  latitude  \
# date
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder   12.9131
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder   12.9131
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder   12.9131
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder   12.9131
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder   12.9131
# ...                         ...              ...         ...       ...
# 2021-07-15          West Bengal   West Midnapore   Kharagpur  22.33933
# 2021-07-15          West Bengal   West Midnapore   Kharagpur  22.33933
# 2021-07-15          West Bengal   West Midnapore   Kharagpur  22.33933
# 2021-07-15          West Bengal   West Midnapore   Kharagpur  22.33933
# 2021-07-15          West Bengal   West Midnapore   Kharagpur  22.33933
#
#            longitude               category           commodity unit  \
# date
# ...

# %%
df1.head()
# Out:
#          date   admin1     admin2     market   latitude  longitude  \
# 1  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 2  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 3  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 4  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#              category      commodity unit pricetype currency price usdprice
# 1  cereals and tubers           Rice   KG    actual      INR   8.0     0.25
# 2  cereals and tubers          Wheat   KG    actual      INR   5.0     0.16
# 3  miscellaneous food          Sugar   KG    actual      INR  13.5     0.43
# 4        oil and fats  Oil (mustard)   KG    actual      INR  31.0     0.99
# 5  cereals and tubers           Rice   KG    actual      INR   6.8     0.22

# %%
df1.truncate(5,10, axis=0)
# Out:
#           date            admin1     admin2     market   latitude  longitude  \
# 5   1994-01-15           Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
# 6   1994-01-15           Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
# 7   1994-01-15           Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
# 8   1994-01-15           Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
# 9   1994-01-15  Himachal Pradesh     Shimla     Shimla  31.103333  77.172222
# 10  1994-01-15  Himachal Pradesh     Shimla     Shimla  31.103333  77.172222
#
#               category      commodity unit pricetype currency  price usdprice
# 5   cereals and tubers           Rice   KG    actual      INR    6.8     0.22
# 6   cereals and tubers          Wheat   KG    actual      INR    6.2      0.2
# 7   miscellaneous food          Sugar   KG    actual      INR   13.5     0.43
# 8         oil and fats  Oil (mustard)   KG    actual      INR   30.0     0.95
# ...

# %%
df3= df1.sort_index()
df3.head()
# Out:
#          date   admin1     admin2     market   latitude  longitude  \
# 1  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 2  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 3  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 4  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#              category      commodity unit pricetype currency price usdprice
# 1  cereals and tubers           Rice   KG    actual      INR   8.0     0.25
# 2  cereals and tubers          Wheat   KG    actual      INR   5.0     0.16
# 3  miscellaneous food          Sugar   KG    actual      INR  13.5     0.43
# 4        oil and fats  Oil (mustard)   KG    actual      INR  31.0     0.99
# 5  cereals and tubers           Rice   KG    actual      INR   6.8     0.22

# %%
df.iloc[1:100:5]
# Out:
#           date            admin1              admin2            market  \
# 1   1994-01-15             Delhi               Delhi             Delhi
# 6   1994-01-15           Gujarat           Ahmadabad         Ahmedabad
# 11  1994-01-15  Himachal Pradesh              Shimla            Shimla
# 16  1994-01-15    Madhya Pradesh              Bhopal            Bhopal
# 21  1994-01-15       Maharashtra         Mumbai city            Mumbai
# 26  1994-01-15         Telangana           Hyderabad         Hyderabad
# 31  1994-01-15       West Bengal             Kolkata           Kolkata
# 36  1994-02-15             Delhi               Delhi             Delhi
# 41  1994-02-15           Gujarat           Ahmadabad         Ahmedabad
# 46  1994-02-15    Madhya Pradesh              Bhopal            Bhopal
# 51  1994-02-15       Maharashtra         Mumbai city            Mumbai
# 56  1994-02-15            Orissa             Khordha      Bhubaneshwar
# ...

# %%
df1.head()
# Out:
#          date   admin1     admin2     market   latitude  longitude  \
# 1  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 2  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 3  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 4  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#              category      commodity unit pricetype currency price usdprice
# 1  cereals and tubers           Rice   KG    actual      INR   8.0     0.25
# 2  cereals and tubers          Wheat   KG    actual      INR   5.0     0.16
# 3  miscellaneous food          Sugar   KG    actual      INR  13.5     0.43
# 4        oil and fats  Oil (mustard)   KG    actual      INR  31.0     0.99
# 5  cereals and tubers           Rice   KG    actual      INR   6.8     0.22

# %%
df2.tail()
# Out:
#                  admin1          admin2     market  latitude longitude  \
# date
# 2021-07-15  West Bengal  West Midnapore  Kharagpur  22.33933  87.22672
# 2021-07-15  West Bengal  West Midnapore  Kharagpur  22.33933  87.22672
# 2021-07-15  West Bengal  West Midnapore  Kharagpur  22.33933  87.22672
# 2021-07-15  West Bengal  West Midnapore  Kharagpur  22.33933  87.22672
# 2021-07-15  West Bengal  West Midnapore  Kharagpur  22.33933  87.22672
#
#                          category        commodity unit pricetype currency  \
# date
# 2021-07-15        pulses and nuts  Lentils (masur)   KG    actual      INR
# 2021-07-15        pulses and nuts  Lentils (moong)   KG    actual      INR
# 2021-07-15        pulses and nuts   Lentils (urad)   KG    actual      INR
# 2021-07-15  vegetables and fruits           Onions   KG    actual      INR
# 2021-07-15  vegetables and fruits         Tomatoes   KG    actual      INR
#
#              price usdprice
# date
# 2021-07-15  104.37      1.4
# ...

# %%
df2.loc['2021-01-15':'2021-02-15', 'price'].max()
# Out:
# 520.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133137 entries, 1 to 133137
# Data columns (total 13 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       133137 non-null  object
#  1   admin1     132348 non-null  object
#  2   admin2     132348 non-null  object
#  3   market     133137 non-null  object
#  4   latitude   132348 non-null  object
#  5   longitude  132348 non-null  object
#  6   category   133137 non-null  object
#  7   commodity  133137 non-null  object
#  8   unit       133137 non-null  object
#  9   pricetype  133137 non-null  object
#  10  currency   133137 non-null  object
#  11  price      133137 non-null  object
#  12  usdprice   133137 non-null  object
# dtypes: object(13)
# memory usage: 13.2+ MB

# %%
df1['admin1'].value_counts()
# Out:
# Uttar Pradesh          9661
# Madhya Pradesh         8665
# Maharashtra            8585
# Tamil Nadu             8493
# Orissa                 8209
# Bihar                  7325
# Haryana                6977
# Rajasthan              6701
# Kerala                 6209
# Punjab                 5808
# Karnataka              5544
# West Bengal            5427
# Gujarat                5295
# Himachal Pradesh       4519
# Delhi                  4096
# Telangana              3745
# Meghalaya              2843
# Andhra Pradesh         2565
# Uttarakhand            2561
# Jharkhand              2469
# Assam                  2336
# Tripura                2043
# Chandigarh             1991
# Andaman and Nicobar    1988
# Puducherry             1912
# Nagaland               1893
# Goa                    1714
# Mizoram                1646
# Chhattisgarh            830
# Sikkim                  172
# Manipur                 126
# Name: admin1, dtype: int64

# %%
df1['admin1'].isnull()
# Out:
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
#           ...
# 133133    False
# 133134    False
# 133135    False
# 133136    False
# 133137    False
# Name: admin1, Length: 133137, dtype: bool

# %%
df1.dropna(inplace = True)

# %%
df1.shape
# Out:
# (132348, 13)

# %%
df1.head()
# Out:
#          date   admin1     admin2     market   latitude  longitude  \
# 1  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 2  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 3  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 4  1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#              category      commodity unit pricetype currency price usdprice
# 1  cereals and tubers           Rice   KG    actual      INR   8.0     0.25
# 2  cereals and tubers          Wheat   KG    actual      INR   5.0     0.16
# 3  miscellaneous food          Sugar   KG    actual      INR  13.5     0.43
# 4        oil and fats  Oil (mustard)   KG    actual      INR  31.0     0.99
# 5  cereals and tubers           Rice   KG    actual      INR   6.8     0.22

# %%
df2.dropna(inplace=True)

# %%
df2.shape
# Out:
# (132348, 12)

# %%
df4 = df2.copy()

# %%
df4.head()
# Out:
#              admin1     admin2     market   latitude  longitude  \
# date
# 1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 1994-01-15    Delhi      Delhi      Delhi  28.666667  77.216667
# 1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.033333  72.616667
#
#                       category      commodity unit pricetype currency price  \
# date
# 1994-01-15  cereals and tubers           Rice   KG    actual      INR   8.0
# 1994-01-15  cereals and tubers          Wheat   KG    actual      INR   5.0
# 1994-01-15  miscellaneous food          Sugar   KG    actual      INR  13.5
# 1994-01-15        oil and fats  Oil (mustard)   KG    actual      INR  31.0
# 1994-01-15  cereals and tubers           Rice   KG    actual      INR   6.8
#
#            usdprice
# date
# 1994-01-15     0.25
# 1994-01-15     0.16
# 1994-01-15     0.43
# ...

# %%
df4.pop('admin1')
# Out:
# date
# 1994-01-15          Delhi
# 1994-01-15          Delhi
# 1994-01-15          Delhi
# 1994-01-15          Delhi
# 1994-01-15        Gujarat
#                  ...
# 2021-07-15    West Bengal
# 2021-07-15    West Bengal
# 2021-07-15    West Bengal
# 2021-07-15    West Bengal
# 2021-07-15    West Bengal
# Name: admin1, Length: 132348, dtype: object

# %%
df4.head()
# Out:
#                admin2     market   latitude  longitude            category  \
# date
# 1994-01-15      Delhi      Delhi  28.666667  77.216667  cereals and tubers
# 1994-01-15      Delhi      Delhi  28.666667  77.216667  cereals and tubers
# 1994-01-15      Delhi      Delhi  28.666667  77.216667  miscellaneous food
# 1994-01-15      Delhi      Delhi  28.666667  77.216667        oil and fats
# 1994-01-15  Ahmadabad  Ahmedabad  23.033333  72.616667  cereals and tubers
#
#                 commodity unit pricetype currency price usdprice
# date
# 1994-01-15           Rice   KG    actual      INR   8.0     0.25
# 1994-01-15          Wheat   KG    actual      INR   5.0     0.16
# 1994-01-15          Sugar   KG    actual      INR  13.5     0.43
# 1994-01-15  Oil (mustard)   KG    actual      INR  31.0     0.99
# 1994-01-15           Rice   KG    actual      INR   6.8     0.22

# %%
df2.xs(('1994-01-15'))
# Out:
#                       admin1           admin2        market   latitude  \
# date
# 1994-01-15             Delhi            Delhi         Delhi  28.666667
# 1994-01-15             Delhi            Delhi         Delhi  28.666667
# 1994-01-15             Delhi            Delhi         Delhi  28.666667
# 1994-01-15             Delhi            Delhi         Delhi  28.666667
# 1994-01-15           Gujarat        Ahmadabad     Ahmedabad  23.033333
# 1994-01-15           Gujarat        Ahmadabad     Ahmedabad  23.033333
# 1994-01-15           Gujarat        Ahmadabad     Ahmedabad  23.033333
# 1994-01-15           Gujarat        Ahmadabad     Ahmedabad  23.033333
# 1994-01-15  Himachal Pradesh           Shimla        Shimla  31.103333
# 1994-01-15  Himachal Pradesh           Shimla        Shimla  31.103333
# 1994-01-15  Himachal Pradesh           Shimla        Shimla  31.103333
# 1994-01-15         Karnataka  Bangalore Urban     Bengaluru  12.962299
# ...

# %%
df2['admin1'].unique()
# Out:
# array(['Delhi', 'Gujarat', 'Himachal Pradesh', 'Karnataka',
#        'Madhya Pradesh', 'Maharashtra', 'Orissa', 'Telangana', 'Tripura',
#        'West Bengal', 'Meghalaya', 'Rajasthan', 'Tamil Nadu', 'Assam',
#        'Kerala', 'Uttar Pradesh', 'Mizoram', 'Bihar', 'Chandigarh',
#        'Jharkhand', 'Nagaland', 'Punjab', 'Uttarakhand', 'Andhra Pradesh',
#        'Haryana', 'Andaman and Nicobar', 'Puducherry', 'Goa',
#        'Chhattisgarh', 'Manipur', 'Sikkim'], dtype=object)

# %%
df2['admin2'].unique()
# Out:
# array(['Delhi', 'Ahmadabad', 'Shimla', 'Bangalore Urban', 'Bhopal',
#        'Mumbai city', 'Khordha', 'Hyderabad', 'West Tripura', 'Kolkata',
#        'East Khasi Hills', 'Bikaner', 'Chennai', 'Kamrup',
#        'Thiruvananthapuram', 'Lucknow', 'Aizawl', 'Patna', 'Chandigarh',
#        'Ranchi', 'Amravati', 'Kohima', 'Amritsar', 'Ludhiana',
#        'Dehra Dun', 'Krishna', 'Rajkot', 'Dindigul', 'Kanpur', 'Banka',
#        'Hisar', 'Karnal', 'Mandi', 'Dharwad', 'Bid', 'Cuttack',
#        'Sambalpur', 'Tiruchchirappalli', 'Agra', 'Varanasi', 'Darjiling',
#        'Indore', 'Dimapur', 'Bathinda', 'Jodhpur', 'Ernakulam', 'Kota',
#        'Andaman Islands', 'Puducherry', 'North Goa', 'Gurgaon',
#        'Panchkula', 'Kozhikode', 'Gwalior', 'Jabalpur', 'Sundargarh',
#        'Chittoor', 'Kurnool', 'Vishakhapatnam', 'Darbhanga', 'Gaya',
#        'Muzaffarpur', 'Purnia', 'Bastar', 'Bilaspur', 'Durg', 'Surguja',
#        'Kachchh', 'Surat', 'Kangra', 'Solan', 'Dakshin Kannad', 'Mysore',
# ...

# %%
df2['market'].unique()
# Out:
# array(['Delhi', 'Ahmedabad', 'Shimla', 'Bengaluru', 'Bhopal', 'Mumbai',
#        'Bhubaneshwar', 'Hyderabad', 'Agartala', 'Kolkata', 'Shillong',
#        'Jaipur', 'Chennai', 'Guwahati', 'Tiruvanantapuram', 'Lucknow',
#        'Aizawl', 'Patna', 'Chandigarh', 'Ranchi', 'Raipur', 'Kohima',
#        'Amritsar', 'Ludhiana', 'Dehradun', 'Vijaywada', 'Rajkot',
#        'Dindigul', 'Kanpur', 'Bhagalpur', 'Hisar', 'Karnal', 'Mandi',
#        'Dharwad', 'Nagpur', 'Cuttack', 'Sambalpur', 'Thiruchirapalli',
#        'Agra', 'Varanasi', 'Siliguri', 'Indore', 'Dimapur', 'Bathinda',
#        'Jodhpur', 'Ernakulam', 'Kota', 'Port Blair', 'Puducherry',
#        'Panaji', 'Gurgaon', 'Panchkula', 'Kozhikode', 'T.Puram',
#        'Gwalior', 'Jabalpur', 'Rourkela', 'Mayabunder', 'Tirupathi',
#        'Kurnool', 'Visakhapatnam', 'Darbhanga', 'Bihar_Gaya',
#        'Muzzafarpur', 'Purnia', 'Jagdalpur', 'Bilaspur', 'Durg',
#        'Ambikapur', 'Bhuj', 'Surat', 'Dharamshala', 'Solan', 'Mangalore',
# ...

# %%
df1['pricetype'].unique()
# Out:
# array(['actual'], dtype=object)

# %%
df1['currency'].unique()
# Out:
# array(['INR'], dtype=object)

# %%
df_tn = df1.loc[(df['admin1']== 'Tamil Nadu') & (df['unit'] == 'KG')]
df_tn
# Out:
#               date      admin1   admin2   market   latitude  longitude  \
# 62      1994-02-15  Tamil Nadu  Chennai  Chennai  13.083333  80.283333
# 63      1994-02-15  Tamil Nadu  Chennai  Chennai  13.083333  80.283333
# 64      1994-02-15  Tamil Nadu  Chennai  Chennai  13.083333  80.283333
# 65      1994-02-15  Tamil Nadu  Chennai  Chennai  13.083333  80.283333
# 106     1994-03-15  Tamil Nadu  Chennai  Chennai  13.083333  80.283333
# ...            ...         ...      ...      ...        ...        ...
# 132473  2021-07-15  Tamil Nadu  Vellore  Vellore   12.91712   79.13248
# 132474  2021-07-15  Tamil Nadu  Vellore  Vellore   12.91712   79.13248
# 132475  2021-07-15  Tamil Nadu  Vellore  Vellore   12.91712   79.13248
# 132476  2021-07-15  Tamil Nadu  Vellore  Vellore   12.91712   79.13248
# 132477  2021-07-15  Tamil Nadu  Vellore  Vellore   12.91712   79.13248
#
#                      category        commodity unit pricetype currency  \
# ...

# %%
df_slice = df_tn[['date', 'market', 'commodity', 'price']]
df_slice
# Out:
#               date   market        commodity   price
# 62      1994-02-15  Chennai             Rice     7.0
# 63      1994-02-15  Chennai            Wheat     8.0
# 64      1994-02-15  Chennai            Sugar    13.4
# 65      1994-02-15  Chennai    Oil (mustard)    37.0
# 106     1994-03-15  Chennai             Rice     7.0
# ...            ...      ...              ...     ...
# 132473  2021-07-15  Vellore  Lentils (masur)    81.7
# 132474  2021-07-15  Vellore  Lentils (moong)  102.35
# 132475  2021-07-15  Vellore   Lentils (urad)  113.26
# 132476  2021-07-15  Vellore           Onions   28.91
# 132477  2021-07-15  Vellore         Tomatoes   17.74
#
# [7488 rows x 4 columns]

# %%
df_slice['market'].unique()
# Out:
# array(['Chennai', 'Dindigul', 'Thiruchirapalli', 'Coimbatore',
#        'Cuddalore', 'Dharmapuri', 'Ramanathapuram', 'Tirunelveli',
#        'Vellore'], dtype=object)

# %%
df_slice['commodity'].unique()
# Out:
# array(['Rice', 'Wheat', 'Sugar', 'Oil (mustard)', 'Potatoes', 'Chickpeas',
#        'Onions', 'Wheat flour', 'Salt (iodised)', 'Oil (groundnut)',
#        'Oil (palm)', 'Oil (sunflower)', 'Lentils (masur)', 'Tomatoes',
#        'Tea (black)', 'Lentils', 'Sugar (jaggery/gur)',
#        'Ghee (vanaspati)', 'Lentils (moong)', 'Lentils (urad)',
#        'Oil (soybean)'], dtype=object)

# %%
df_slice.loc[df_slice['commodity'].isin(['Rice'])]
# Out:
#               date           market commodity  price
# 62      1994-02-15          Chennai      Rice    7.0
# 106     1994-03-15          Chennai      Rice    7.0
# 153     1994-04-15          Chennai      Rice   7.25
# 190     1994-05-15          Chennai      Rice   7.25
# 228     1994-06-15          Chennai      Rice    7.5
# ...            ...              ...       ...    ...
# 132380  2021-07-15         Dindigul      Rice   52.0
# 132400  2021-07-15   Ramanathapuram      Rice   42.0
# 132419  2021-07-15  Thiruchirapalli      Rice  54.48
# 132439  2021-07-15      Tirunelveli      Rice  32.55
# 132459  2021-07-15          Vellore      Rice   46.0
#
# [623 rows x 4 columns]

# %%
df1['category'].unique()
# Out:
# array(['cereals and tubers', 'miscellaneous food', 'oil and fats',
#        'pulses and nuts', 'vegetables and fruits', 'milk and dairy'],
#       dtype=object)

# %%
dfcer_tub = df1.loc[df1['category']== 'cereals and tubers']
dfcer_tub
# Out:
#               date            admin1          admin2     market   latitude  \
# 1       1994-01-15             Delhi           Delhi      Delhi  28.666667
# 2       1994-01-15             Delhi           Delhi      Delhi  28.666667
# 5       1994-01-15           Gujarat       Ahmadabad  Ahmedabad  23.033333
# 6       1994-01-15           Gujarat       Ahmadabad  Ahmedabad  23.033333
# 9       1994-01-15  Himachal Pradesh          Shimla     Shimla  31.103333
# ...            ...               ...             ...        ...        ...
# 133099  2021-07-15       West Bengal  Uttar Dinajpur    Raiganj   25.63305
# 133117  2021-07-15       West Bengal  West Midnapore  Kharagpur   22.33933
# 133118  2021-07-15       West Bengal  West Midnapore  Kharagpur   22.33933
# 133119  2021-07-15       West Bengal  West Midnapore  Kharagpur   22.33933
# 133120  2021-07-15       West Bengal  West Midnapore  Kharagpur   22.33933
#
# ...

# %%
df_potatoes = df1.loc[df1['commodity']== 'Potatoes']
df_potatoes
# Out:
#               date       admin1          admin2     market   latitude  \
# 2432    2000-01-15        Delhi           Delhi      Delhi  28.666667
# 2456    2000-01-15  Maharashtra     Mumbai city     Mumbai     18.975
# 2472    2000-01-15   Tamil Nadu         Chennai    Chennai  13.083333
# 2500    2000-02-15        Delhi           Delhi      Delhi  28.666667
# 2524    2000-02-15  Maharashtra     Mumbai city     Mumbai     18.975
# ...            ...          ...             ...        ...        ...
# 133036  2021-07-15  West Bengal         Kolkata    Kolkata  22.569722
# 133055  2021-07-15  West Bengal          Maldah      Malda   25.01171
# 133075  2021-07-15  West Bengal        Puruliya    Purulia   23.33237
# 133096  2021-07-15  West Bengal  Uttar Dinajpur    Raiganj   25.63305
# 133117  2021-07-15  West Bengal  West Midnapore  Kharagpur   22.33933
#
#         longitude            category commodity unit pricetype currency  \
# ...

# %%
df
# Out:
#               date       admin1          admin2            market   latitude  \
# 0            #date   #adm1+name      #adm2+name  #loc+market+name   #geo+lat
# 1       1994-01-15        Delhi           Delhi             Delhi  28.666667
# 2       1994-01-15        Delhi           Delhi             Delhi  28.666667
# 3       1994-01-15        Delhi           Delhi             Delhi  28.666667
# 4       1994-01-15        Delhi           Delhi             Delhi  28.666667
# ...            ...          ...             ...               ...        ...
# 133133  2021-07-15  West Bengal  West Midnapore         Kharagpur   22.33933
# 133134  2021-07-15  West Bengal  West Midnapore         Kharagpur   22.33933
# 133135  2021-07-15  West Bengal  West Midnapore         Kharagpur   22.33933
# 133136  2021-07-15  West Bengal  West Midnapore         Kharagpur   22.33933
# 133137  2021-07-15  West Bengal  West Midnapore         Kharagpur   22.33933
#
# ...

# %%
df_potatoes['price'].dtypes
# Out:
# dtype('O')

# %%
df_potatoes.dtypes
# Out:
# date         object
# admin1       object
# admin2       object
# market       object
# latitude     object
# longitude    object
# category     object
# commodity    object
# unit         object
# pricetype    object
# currency     object
# price        object
# usdprice     object
# dtype: object

# %%
df1['price'].sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 df1['price'].sort_values()
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:3526, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3524 # GH 35922. Make sorting stable by leveraging nargsort
#    3525 values_to_sort = ensure_key_mapped(self, key)._values if key else self._values
# ...

# %%
df_exp = df1.copy()

# %%
df_exp.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'unit', 'pricetype', 'currency', 'price',
#        'usdprice'],
#       dtype='object')

# %%
df_exp['date'] = df_exp['date'].astype('datetime64')
df_exp['admin1'] = df_exp['admin1'].astype('str')
df_exp['admin2'] = df_exp['admin2'].astype('str')
df_exp['market'] = df_exp['market'].astype('str')
df_exp['latitude'] = df_exp['latitude'].astype('float16')
df_exp['longitude'] = df_exp['longitude'].astype('float16')
df_exp['category'] = df_exp['category'].astype('str')
df_exp['commodity'] = df_exp['commodity'].astype('str')
df_exp['unit'] = df_exp['unit'].astype('str')
df_exp['pricetype'] = df_exp['pricetype'].astype('str')
df_exp['currency'] = df_exp['currency'].astype('str')
df_exp['price'] = df_exp['price'].astype('float32')
df_exp[ 'usdprice'] = df_exp['usdprice'].astype('float32')

# %%
df_exp.dtypes
# Out:
# date         datetime64[ns]
# admin1               object
# admin2               object
# market               object
# latitude            float16
# longitude           float16
# category             object
# commodity            object
# unit                 object
# pricetype            object
# currency             object
# price               float32
# usdprice            float32
# dtype: object

# %%
df_exp['price'].sort_values()
# Out:
# 2787         2.50
# 2708         2.69
# 2802         2.79
# 5255         2.81
# 5172         2.83
#            ...
# 106220    4900.00
# 107267    4900.00
# 105176    4900.00
# 104129    4900.00
# 103084    4910.00
# Name: price, Length: 132348, dtype: float32

# %%
df_exp.head()
# Out:
#         date   admin1     admin2     market   latitude  longitude  \
# 1 1994-01-15    Delhi      Delhi      Delhi  28.671875    77.1875
# 2 1994-01-15    Delhi      Delhi      Delhi  28.671875    77.1875
# 3 1994-01-15    Delhi      Delhi      Delhi  28.671875    77.1875
# 4 1994-01-15    Delhi      Delhi      Delhi  28.671875    77.1875
# 5 1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.031250    72.6250
#
#              category      commodity unit pricetype currency  price  usdprice
# 1  cereals and tubers           Rice   KG    actual      INR    8.0      0.25
# 2  cereals and tubers          Wheat   KG    actual      INR    5.0      0.16
# 3  miscellaneous food          Sugar   KG    actual      INR   13.5      0.43
# 4        oil and fats  Oil (mustard)   KG    actual      INR   31.0      0.99
# 5  cereals and tubers           Rice   KG    actual      INR    6.8      0.22

# %%
df_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132348 entries, 1 to 133137
# Data columns (total 13 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       132348 non-null  datetime64[ns]
#  1   admin1     132348 non-null  object
#  2   admin2     132348 non-null  object
#  3   market     132348 non-null  object
#  4   latitude   132348 non-null  float16
#  5   longitude  132348 non-null  float16
#  6   category   132348 non-null  object
#  7   commodity  132348 non-null  object
#  8   unit       132348 non-null  object
#  9   pricetype  132348 non-null  object
#  10  currency   132348 non-null  object
#  11  price      132348 non-null  float32
#  12  usdprice   132348 non-null  float32
# dtypes: datetime64[ns](1), float16(2), float32(2), object(8)
# memory usage: 11.6+ MB

# %%
df_potatoes1 = df_exp.loc[df_exp['commodity']== 'Potatoes']
df_potatoes1
# Out:
#              date       admin1          admin2     market   latitude  \
# 2432   2000-01-15        Delhi           Delhi      Delhi  28.671875
# 2456   2000-01-15  Maharashtra     Mumbai city     Mumbai  18.968750
# 2472   2000-01-15   Tamil Nadu         Chennai    Chennai  13.085938
# 2500   2000-02-15        Delhi           Delhi      Delhi  28.671875
# 2524   2000-02-15  Maharashtra     Mumbai city     Mumbai  18.968750
# ...           ...          ...             ...        ...        ...
# 133036 2021-07-15  West Bengal         Kolkata    Kolkata  22.562500
# 133055 2021-07-15  West Bengal          Maldah      Malda  25.015625
# 133075 2021-07-15  West Bengal        Puruliya    Purulia  23.328125
# 133096 2021-07-15  West Bengal  Uttar Dinajpur    Raiganj  25.640625
# 133117 2021-07-15  West Bengal  West Midnapore  Kharagpur  22.343750
#
#         longitude            category commodity unit pricetype currency  \
# ...

# %%
df_potatoes1[['date', 'price']]
# Out:
#              date  price
# 2432   2000-01-15   4.00
# 2456   2000-01-15   7.15
# 2472   2000-01-15   5.55
# 2500   2000-02-15   3.57
# 2524   2000-02-15   6.33
# ...           ...    ...
# 133036 2021-07-15  14.29
# 133055 2021-07-15  15.00
# 133075 2021-07-15  13.35
# 133096 2021-07-15  15.29
# 133117 2021-07-15  15.00
#
# [6839 rows x 2 columns]

# %%
df_potatoes1.to_csv('potatoes1.csv', index = False)

# %%
df_exp[(df_exp['date'] > '2016-06-01') & (df_exp['date'] < '2016-12-31')]
# Out:
#             date               admin1           admin2      market   latitude  \
# 55516 2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair  11.664062
# 55517 2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair  11.664062
# 55518 2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair  11.664062
# 55519 2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair  11.664062
# 55520 2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair  11.664062
# ...          ...                  ...              ...         ...        ...
# 63400 2016-12-15          West Bengal          Kolkata     Kolkata  22.562500
# 63401 2016-12-15          West Bengal          Kolkata     Kolkata  22.562500
# 63402 2016-12-15          West Bengal          Kolkata     Kolkata  22.562500
# 63403 2016-12-15          West Bengal          Kolkata     Kolkata  22.562500
# 63404 2016-12-15          West Bengal          Kolkata     Kolkata  22.562500
#
# ...

# %%
df_exp.head()
# Out:
#         date   admin1     admin2     market   latitude  longitude  \
# 1 1994-01-15    Delhi      Delhi      Delhi  28.671875    77.1875
# 2 1994-01-15    Delhi      Delhi      Delhi  28.671875    77.1875
# 3 1994-01-15    Delhi      Delhi      Delhi  28.671875    77.1875
# 4 1994-01-15    Delhi      Delhi      Delhi  28.671875    77.1875
# 5 1994-01-15  Gujarat  Ahmadabad  Ahmedabad  23.031250    72.6250
#
#              category      commodity unit pricetype currency  price  usdprice
# 1  cereals and tubers           Rice   KG    actual      INR    8.0      0.25
# 2  cereals and tubers          Wheat   KG    actual      INR    5.0      0.16
# 3  miscellaneous food          Sugar   KG    actual      INR   13.5      0.43
# 4        oil and fats  Oil (mustard)   KG    actual      INR   31.0      0.99
# 5  cereals and tubers           Rice   KG    actual      INR    6.8      0.22

# %%
df_exp.to_csv('optimised_food_price.csv', index = False)
