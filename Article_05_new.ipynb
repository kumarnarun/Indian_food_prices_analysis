# %%
import pandas as pd

# %%
df = pd.read_csv('optimised_food_price.csv')
df.head()
# Out:
#          date   admin1     admin2     market  latitude  longitude  \
# 0  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 2  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 3  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 4  1994-01-15  Gujarat  Ahmadabad  Ahmedabad     23.03       72.6
#
#              category      commodity unit pricetype currency  price  usdprice
# 0  cereals and tubers           Rice   KG    actual      INR    8.0      0.25
# 1  cereals and tubers          Wheat   KG    actual      INR    5.0      0.16
# 2  miscellaneous food          Sugar   KG    actual      INR   13.5      0.43
# 3        oil and fats  Oil (mustard)   KG    actual      INR   31.0      0.99
# 4  cereals and tubers           Rice   KG    actual      INR    6.8      0.22

# %%
df.to_excel('India_food_prices.xlsx',index = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132348 entries, 0 to 132347
# Data columns (total 13 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       132348 non-null  object
#  1   admin1     132348 non-null  object
#  2   admin2     132348 non-null  object
#  3   market     132348 non-null  object
#  4   latitude   132348 non-null  float64
#  5   longitude  132348 non-null  float64
#  6   category   132348 non-null  object
#  7   commodity  132348 non-null  object
#  8   unit       132348 non-null  object
#  9   pricetype  132348 non-null  object
#  10  currency   132348 non-null  object
#  11  price      132348 non-null  float64
#  12  usdprice   132348 non-null  float64
# dtypes: float64(4), object(9)
# memory usage: 13.1+ MB

# %%
df.iloc[[0]]
# Out:
#          date admin1 admin2 market  latitude  longitude            category  \
# 0  1994-01-15  Delhi  Delhi  Delhi     28.67       77.2  cereals and tubers
#
#   commodity unit pricetype currency  price  usdprice
# 0      Rice   KG    actual      INR    8.0      0.25

# %%
df.dtypes
# Out:
# date          object
# admin1        object
# admin2        object
# market        object
# latitude     float64
# longitude    float64
# category      object
# commodity     object
# unit          object
# pricetype     object
# currency      object
# price        float64
# usdprice     float64
# dtype: object

# %%
df.infer_objects().dtypes
# Out:
# date          object
# admin1        object
# admin2        object
# market        object
# latitude     float64
# longitude    float64
# category      object
# commodity     object
# unit          object
# pricetype     object
# currency      object
# price        float64
# usdprice     float64
# dtype: object

# %%
df.iloc[0:5,0:5]
# Out:
#          date   admin1     admin2     market  latitude
# 0  1994-01-15    Delhi      Delhi      Delhi     28.67
# 1  1994-01-15    Delhi      Delhi      Delhi     28.67
# 2  1994-01-15    Delhi      Delhi      Delhi     28.67
# 3  1994-01-15    Delhi      Delhi      Delhi     28.67
# 4  1994-01-15  Gujarat  Ahmadabad  Ahmedabad     23.03

# %%
df.shape[0]
# Out:
# 132348

# %%
mid_rw1 = int(df.shape[0]/2)
mid_rw1
# Out:
# 66174

# %%
df.iloc[mid_rw1:mid_rw1+5, :]
# Out:
#              date      admin1   admin2   market  latitude  longitude  \
# 66174  2017-03-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 66175  2017-03-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 66176  2017-03-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 66177  2017-03-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 66178  2017-03-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
#
#                  category commodity    unit pricetype currency    price  \
# 66174  cereals and tubers  Potatoes      KG    actual      INR    14.16
# 66175  cereals and tubers      Rice  100 KG    actual      INR  3132.26
# 66176  cereals and tubers      Rice      KG    actual      INR    35.45
# 66177  cereals and tubers     Wheat  100 KG    actual      INR  2500.00
# 66178  cereals and tubers     Wheat      KG    actual      INR    34.00
#
#        usdprice
# 66174      0.22
# 66175     47.73
# 66176      0.54
# 66177     38.10
# 66178      0.52

# %%
mid_rw = int(len(df)/2)
print(mid_rw)
df.iloc[mid_rw-5:mid_rw, :]
# Out:
# 66174
#              date     admin1 admin2 market  latitude  longitude  \
# 66169  2017-03-15  Rajasthan   Kota   Kota     25.19       75.8
# 66170  2017-03-15  Rajasthan   Kota   Kota     25.19       75.8
# 66171  2017-03-15  Rajasthan   Kota   Kota     25.19       75.8
# 66172  2017-03-15  Rajasthan   Kota   Kota     25.19       75.8
# 66173  2017-03-15  Rajasthan   Kota   Kota     25.19       75.8
#
#                     category        commodity unit pricetype currency  price  \
# 66169        pulses and nuts  Lentils (masur)   KG    actual      INR  60.00
# 66170        pulses and nuts  Lentils (moong)   KG    actual      INR  50.00
# 66171        pulses and nuts   Lentils (urad)   KG    actual      INR  80.00
# 66172  vegetables and fruits           Onions   KG    actual      INR  11.52
# 66173  vegetables and fruits         Tomatoes   KG    actual      INR   9.13
#
#        usdprice
# 66169      0.91
# 66170      0.76
# 66171      1.22
# 66172      0.18
# 66173      0.14

# %%
df.iloc[lambda df: df.index % 2 == 0]
# Out:
#               date            admin1          admin2     market  latitude  \
# 0       1994-01-15             Delhi           Delhi      Delhi     28.67
# 2       1994-01-15             Delhi           Delhi      Delhi     28.67
# 4       1994-01-15           Gujarat       Ahmadabad  Ahmedabad     23.03
# 6       1994-01-15           Gujarat       Ahmadabad  Ahmedabad     23.03
# 8       1994-01-15  Himachal Pradesh          Shimla     Shimla     31.11
# ...            ...               ...             ...        ...       ...
# 132338  2021-07-15       West Bengal  West Midnapore  Kharagpur     22.34
# 132340  2021-07-15       West Bengal  West Midnapore  Kharagpur     22.34
# 132342  2021-07-15       West Bengal  West Midnapore  Kharagpur     22.34
# 132344  2021-07-15       West Bengal  West Midnapore  Kharagpur     22.34
# 132346  2021-07-15       West Bengal  West Midnapore  Kharagpur     22.34
#
#         longitude               category        commodity unit pricetype  \
# ...

# %%
df.tail()
# Out:
#               date       admin1          admin2     market  latitude  \
# 132343  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132344  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132345  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132346  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132347  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
#
#         longitude               category        commodity unit pricetype  \
# 132343      87.25        pulses and nuts  Lentils (masur)   KG    actual
# 132344      87.25        pulses and nuts  Lentils (moong)   KG    actual
# 132345      87.25        pulses and nuts   Lentils (urad)   KG    actual
# 132346      87.25  vegetables and fruits           Onions   KG    actual
# 132347      87.25  vegetables and fruits         Tomatoes   KG    actual
#
#        currency   price  usdprice
# 132343      INR  104.37      1.40
# 132344      INR  115.00      1.54
# ...

# %%
df.iloc[0:5, :]
# Out:
#          date   admin1     admin2     market  latitude  longitude  \
# 0  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 2  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 3  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 4  1994-01-15  Gujarat  Ahmadabad  Ahmedabad     23.03       72.6
#
#              category      commodity unit pricetype currency  price  usdprice
# 0  cereals and tubers           Rice   KG    actual      INR    8.0      0.25
# 1  cereals and tubers          Wheat   KG    actual      INR    5.0      0.16
# 2  miscellaneous food          Sugar   KG    actual      INR   13.5      0.43
# 3        oil and fats  Oil (mustard)   KG    actual      INR   31.0      0.99
# 4  cereals and tubers           Rice   KG    actual      INR    6.8      0.22

# %%
df.iloc[:,[0,11]]
# Out:
#               date   price
# 0       1994-01-15    8.00
# 1       1994-01-15    5.00
# 2       1994-01-15   13.50
# 3       1994-01-15   31.00
# 4       1994-01-15    6.80
# ...            ...     ...
# 132343  2021-07-15  104.37
# 132344  2021-07-15  115.00
# 132345  2021-07-15  105.00
# 132346  2021-07-15   30.00
# 132347  2021-07-15   40.00
#
# [132348 rows x 2 columns]

# %%
df.iloc[-5:, lambda df: [0,10,11,12]]
# Out:
#               date currency   price  usdprice
# 132343  2021-07-15      INR  104.37      1.40
# 132344  2021-07-15      INR  115.00      1.54
# 132345  2021-07-15      INR  105.00      1.41
# 132346  2021-07-15      INR   30.00      0.40
# 132347  2021-07-15      INR   40.00      0.54

# %%
df
# Out:
#               date       admin1          admin2     market  latitude  \
# 0       1994-01-15        Delhi           Delhi      Delhi     28.67
# 1       1994-01-15        Delhi           Delhi      Delhi     28.67
# 2       1994-01-15        Delhi           Delhi      Delhi     28.67
# 3       1994-01-15        Delhi           Delhi      Delhi     28.67
# 4       1994-01-15      Gujarat       Ahmadabad  Ahmedabad     23.03
# ...            ...          ...             ...        ...       ...
# 132343  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132344  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132345  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132346  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132347  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
#
#         longitude               category        commodity unit pricetype  \
# ...

# %%
df.iloc[-5:, [0,10,11,12]]
# Out:
#               date currency   price  usdprice
# 132343  2021-07-15      INR  104.37      1.40
# 132344  2021-07-15      INR  115.00      1.54
# 132345  2021-07-15      INR  105.00      1.41
# 132346  2021-07-15      INR   30.00      0.40
# 132347  2021-07-15      INR   40.00      0.54

# %%
df1 = df.copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132348 entries, 0 to 132347
# Data columns (total 13 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       132348 non-null  object
#  1   admin1     132348 non-null  object
#  2   admin2     132348 non-null  object
#  3   market     132348 non-null  object
#  4   latitude   132348 non-null  float64
#  5   longitude  132348 non-null  float64
#  6   category   132348 non-null  object
#  7   commodity  132348 non-null  object
#  8   unit       132348 non-null  object
#  9   pricetype  132348 non-null  object
#  10  currency   132348 non-null  object
#  11  price      132348 non-null  float64
#  12  usdprice   132348 non-null  float64
# dtypes: float64(4), object(9)
# memory usage: 13.1+ MB

# %%
df1.head()
# Out:
#          date   admin1     admin2     market  latitude  longitude  \
# 0  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 2  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 3  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 4  1994-01-15  Gujarat  Ahmadabad  Ahmedabad     23.03       72.6
#
#              category      commodity unit pricetype currency  price  usdprice
# 0  cereals and tubers           Rice   KG    actual      INR    8.0      0.25
# 1  cereals and tubers          Wheat   KG    actual      INR    5.0      0.16
# 2  miscellaneous food          Sugar   KG    actual      INR   13.5      0.43
# 3        oil and fats  Oil (mustard)   KG    actual      INR   31.0      0.99
# 4  cereals and tubers           Rice   KG    actual      INR    6.8      0.22

# %%
df1.set_index('date', inplace = True)

# %%
df1.head()
# Out:
#              admin1     admin2     market  latitude  longitude  \
# date
# 1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1994-01-15  Gujarat  Ahmadabad  Ahmedabad     23.03       72.6
#
#                       category      commodity unit pricetype currency  price  \
# date
# 1994-01-15  cereals and tubers           Rice   KG    actual      INR    8.0
# 1994-01-15  cereals and tubers          Wheat   KG    actual      INR    5.0
# 1994-01-15  miscellaneous food          Sugar   KG    actual      INR   13.5
# 1994-01-15        oil and fats  Oil (mustard)   KG    actual      INR   31.0
# 1994-01-15  cereals and tubers           Rice   KG    actual      INR    6.8
#
#             usdprice
# date
# 1994-01-15      0.25
# 1994-01-15      0.16
# 1994-01-15      0.43
# ...

# %%
df1.iloc[1:2]
# Out:
#            admin1 admin2 market  latitude  longitude            category  \
# date
# 1994-01-15  Delhi  Delhi  Delhi     28.67       77.2  cereals and tubers
#
#            commodity unit pricetype currency  price  usdprice
# date
# 1994-01-15     Wheat   KG    actual      INR    5.0      0.16

# %%
df1.tail()
# Out:
#                  admin1          admin2     market  latitude  longitude  \
# date
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
#
#                          category        commodity unit pricetype currency  \
# date
# 2021-07-15        pulses and nuts  Lentils (masur)   KG    actual      INR
# 2021-07-15        pulses and nuts  Lentils (moong)   KG    actual      INR
# 2021-07-15        pulses and nuts   Lentils (urad)   KG    actual      INR
# 2021-07-15  vegetables and fruits           Onions   KG    actual      INR
# 2021-07-15  vegetables and fruits         Tomatoes   KG    actual      INR
#
#              price  usdprice
# date
# 2021-07-15  104.37      1.40
# ...

# %%
df.truncate(50,100, axis =0)
# Out:
#            date            admin1              admin2            market  \
# 50   1994-02-15       Maharashtra         Mumbai city            Mumbai
# 51   1994-02-15         Meghalaya    East Khasi Hills          Shillong
# 52   1994-02-15         Meghalaya    East Khasi Hills          Shillong
# 53   1994-02-15         Meghalaya    East Khasi Hills          Shillong
# 54   1994-02-15            Orissa             Khordha      Bhubaneshwar
# 55   1994-02-15            Orissa             Khordha      Bhubaneshwar
# 56   1994-02-15            Orissa             Khordha      Bhubaneshwar
# 57   1994-02-15         Rajasthan             Bikaner            Jaipur
# 58   1994-02-15         Rajasthan             Bikaner            Jaipur
# 59   1994-02-15         Rajasthan             Bikaner            Jaipur
# 60   1994-02-15         Rajasthan             Bikaner            Jaipur
# 61   1994-02-15        Tamil Nadu             Chennai           Chennai
# ...

# %%
df1.truncate('2021-01-01', '2022-01-01')
# Out:
#                          admin1           admin2      market  latitude  \
# date
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder    12.914
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder    12.914
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder    12.914
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder    12.914
# 2021-01-15  Andaman and Nicobar  Andaman Islands  Mayabunder    12.914
# ...                         ...              ...         ...       ...
# 2021-07-15          West Bengal   West Midnapore   Kharagpur    22.340
# 2021-07-15          West Bengal   West Midnapore   Kharagpur    22.340
# 2021-07-15          West Bengal   West Midnapore   Kharagpur    22.340
# 2021-07-15          West Bengal   West Midnapore   Kharagpur    22.340
# 2021-07-15          West Bengal   West Midnapore   Kharagpur    22.340
#
#             longitude               category           commodity unit  \
# date
# ...

# %%
df.head()
# Out:
#          date   admin1     admin2     market  latitude  longitude  \
# 0  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 2  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 3  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 4  1994-01-15  Gujarat  Ahmadabad  Ahmedabad     23.03       72.6
#
#              category      commodity unit pricetype currency  price  usdprice
# 0  cereals and tubers           Rice   KG    actual      INR    8.0      0.25
# 1  cereals and tubers          Wheat   KG    actual      INR    5.0      0.16
# 2  miscellaneous food          Sugar   KG    actual      INR   13.5      0.43
# 3        oil and fats  Oil (mustard)   KG    actual      INR   31.0      0.99
# 4  cereals and tubers           Rice   KG    actual      INR    6.8      0.22

# %%
df.loc[5]
# Out:
# date                 1994-01-15
# admin1                  Gujarat
# admin2                Ahmadabad
# market                Ahmedabad
# latitude                  23.03
# longitude                  72.6
# category     cereals and tubers
# commodity                 Wheat
# unit                         KG
# pricetype                actual
# currency                    INR
# price                       6.2
# usdprice                    0.2
# Name: 5, dtype: object

# %%
df.loc[[2222,2500,100000]]
# Out:
#               date     admin1     admin2     market  latitude  longitude  \
# 2222    1999-04-15  Rajasthan    Bikaner     Jaipur     28.89      74.06
# 2500    2000-02-15      Delhi      Delhi      Delhi     28.67      77.20
# 100000  2020-03-15     Orissa  Sambalpur  Sambalpur     21.45      83.94
#
#                      category commodity    unit pricetype currency    price  \
# 2222       cereals and tubers      Rice      KG    actual      INR    12.00
# 2500       cereals and tubers      Rice  100 KG    actual      INR  1050.00
# 100000  vegetables and fruits    Onions      KG    actual      INR    29.83
#
#         usdprice
# 2222        0.28
# 2500       24.06
# 100000      0.40

# %%
df.loc[100:200,'date','price']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 df.loc[100:200,'date','price']
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexing.py:1143, in _LocIndexer._getitem_tuple(self, tup)
#    1140     return self._getitem_lowerdim(tup)
#    1142 # no multi-index, so validate all of the indexers
# -> 1143 tup = self._validate_tuple_indexer(tup)
#    1145 # ugly hack for GH #836
#    1146 if self._multi_take_opportunity(tup):
#
# ...

# %%
df.loc[::5]
# Out:
#               date            admin1          admin2     market  latitude  \
# 0       1994-01-15             Delhi           Delhi      Delhi     28.67
# 5       1994-01-15           Gujarat       Ahmadabad  Ahmedabad     23.03
# 10      1994-01-15  Himachal Pradesh          Shimla     Shimla     31.11
# 15      1994-01-15    Madhya Pradesh          Bhopal     Bhopal     23.27
# 20      1994-01-15       Maharashtra     Mumbai city     Mumbai     18.97
# ...            ...               ...             ...        ...       ...
# 132325  2021-07-15       West Bengal  Uttar Dinajpur    Raiganj     25.64
# 132330  2021-07-15       West Bengal  West Midnapore  Kharagpur     22.34
# 132335  2021-07-15       West Bengal  West Midnapore  Kharagpur     22.34
# 132340  2021-07-15       West Bengal  West Midnapore  Kharagpur     22.34
# 132345  2021-07-15       West Bengal  West Midnapore  Kharagpur     22.34
#
#         longitude               category       commodity unit pricetype  \
# ...

# %%
df.loc[0:5]
# Out:
#          date   admin1     admin2     market  latitude  longitude  \
# 0  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 2  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 3  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 4  1994-01-15  Gujarat  Ahmadabad  Ahmedabad     23.03       72.6
# 5  1994-01-15  Gujarat  Ahmadabad  Ahmedabad     23.03       72.6
#
#              category      commodity unit pricetype currency  price  usdprice
# 0  cereals and tubers           Rice   KG    actual      INR    8.0      0.25
# 1  cereals and tubers          Wheat   KG    actual      INR    5.0      0.16
# 2  miscellaneous food          Sugar   KG    actual      INR   13.5      0.43
# 3        oil and fats  Oil (mustard)   KG    actual      INR   31.0      0.99
# 4  cereals and tubers           Rice   KG    actual      INR    6.8      0.22
# ...

# %%
df.loc[100:200, 'date':'price':11]
# Out:
#            date  price
# 100  1994-03-15   33.0
# 101  1994-03-15    9.0
# 102  1994-03-15    4.8
# 103  1994-03-15   13.6
# 104  1994-03-15   29.0
# ..          ...    ...
# 196  1994-05-15   38.0
# 197  1994-05-15   16.0
# 198  1994-05-15   37.0
# 199  1994-05-15    6.9
# 200  1994-05-15   15.0
#
# [101 rows x 2 columns]

# %%
df.loc[::]
# Out:
#               date       admin1          admin2     market  latitude  \
# 0       1994-01-15        Delhi           Delhi      Delhi     28.67
# 1       1994-01-15        Delhi           Delhi      Delhi     28.67
# 2       1994-01-15        Delhi           Delhi      Delhi     28.67
# 3       1994-01-15        Delhi           Delhi      Delhi     28.67
# 4       1994-01-15      Gujarat       Ahmadabad  Ahmedabad     23.03
# ...            ...          ...             ...        ...       ...
# 132343  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132344  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132345  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132346  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
# 132347  2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34
#
#         longitude               category        commodity unit pricetype  \
# ...

# %%
df1.loc['1994-03-15', lambda df1: ['market','price']]
# Out:
#                       market  price
# date
# 1994-03-15          Guwahati   6.50
# 1994-03-15          Guwahati  13.50
# 1994-03-15          Guwahati  27.00
# 1994-03-15             Delhi   8.00
# 1994-03-15             Delhi   5.00
# 1994-03-15             Delhi  13.50
# 1994-03-15             Delhi  30.00
# 1994-03-15         Ahmedabad   7.25
# 1994-03-15         Ahmedabad   6.50
# 1994-03-15         Ahmedabad  13.60
# 1994-03-15         Ahmedabad  31.00
# 1994-03-15            Shimla   9.00
# 1994-03-15            Shimla  14.50
# 1994-03-15            Shimla  37.50
# 1994-03-15         Bengaluru   6.50
# 1994-03-15         Bengaluru  13.70
# 1994-03-15  Tiruvanantapuram   8.20
# 1994-03-15  Tiruvanantapuram  10.00
# 1994-03-15  Tiruvanantapuram  14.20
# 1994-03-15            Bhopal   4.00
# 1994-03-15            Bhopal  14.00
# 1994-03-15            Bhopal  32.00
# 1994-03-15            Mumbai   8.00
# 1994-03-15            Mumbai   8.00
# 1994-03-15            Mumbai  14.00
# ...

# %%
df1.loc['1994-01-01':'2000-01-01',['market','commodity','price']]
# Out:
#                market      commodity  price
# date
# 1994-01-15      Delhi           Rice    8.0
# 1994-01-15      Delhi          Wheat    5.0
# 1994-01-15      Delhi          Sugar   13.5
# 1994-01-15      Delhi  Oil (mustard)   31.0
# 1994-01-15  Ahmedabad           Rice    6.8
# ...               ...            ...    ...
# 1999-12-15  Hyderabad          Wheat   10.0
# 1999-12-15   Agartala           Rice   12.0
# 1999-12-15    Lucknow           Rice    8.5
# 1999-12-15    Lucknow          Wheat    7.5
# 1999-12-15    Kolkata           Rice   13.0
#
# [2422 rows x 3 columns]

# %%
df1.loc['1997-01-01':'2000-01-01', 'price']
# Out:
# date
# 1997-01-15     8.5
# 1997-01-15     9.5
# 1997-01-15     8.5
# 1997-01-15    12.0
# 1997-01-15     8.0
#               ...
# 1999-12-15    10.0
# 1999-12-15    12.0
# 1999-12-15     8.5
# 1999-12-15     7.5
# 1999-12-15    13.0
# Name: price, Length: 954, dtype: float64

# %%
df1.loc['2015-01-01':'2016-01-01', 'unit':'price']
# Out:
#            unit pricetype currency   price
# date
# 2015-01-15   KG    actual      INR   29.67
# 2015-01-15   KG    actual      INR   36.00
# 2015-01-15   KG    actual      INR   27.00
# 2015-01-15   KG    actual      INR   44.83
# 2015-01-15    L    actual      INR   56.00
# ...         ...       ...      ...     ...
# 2015-12-15   KG    actual      INR   78.00
# 2015-12-15   KG    actual      INR  114.29
# 2015-12-15   KG    actual      INR  130.29
# 2015-12-15   KG    actual      INR   31.19
# 2015-12-15   KG    actual      INR   27.14
#
# [11720 rows x 4 columns]

# %%
df1.loc['2010-01-01':'2011-01-01', 'price':]
# Out:
#             price  usdprice
# date
# 2010-01-15   16.0      0.35
# 2010-01-15   17.0      0.37
# 2010-01-15   36.0      0.79
# 2010-01-15   63.0      1.38
# 2010-01-15    9.5      0.21
# ...           ...       ...
# 2010-12-15   33.0      0.73
# 2010-12-15   74.0      1.63
# 2010-12-15   20.0      0.44
# 2010-12-15   33.0      0.73
# 2010-12-15   69.0      1.52
#
# [1387 rows x 2 columns]

# %%
df1.loc['2000-01-01':, :]
# Out:
#                  admin1          admin2     market  latitude  longitude  \
# date
# 2000-01-15        Assam          Kamrup   Guwahati     26.19      91.75
# 2000-01-15        Assam          Kamrup   Guwahati     26.19      91.75
# 2000-01-15        Assam          Kamrup   Guwahati     26.19      91.75
# 2000-01-15        Bihar           Patna      Patna     25.60      85.10
# 2000-01-15        Bihar           Patna      Patna     25.60      85.10
# ...                 ...             ...        ...       ...        ...
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
# 2021-07-15  West Bengal  West Midnapore  Kharagpur     22.34      87.25
#
#                          category        commodity    unit pricetype currency  \
# date
# ...

# %%
df['date'].dtypes
# Out:
# dtype('O')

# %%
df.loc[df['price']>1000]
# Out:
#               date       admin1       admin2   market  latitude  longitude  \
# 2432    2000-01-15        Delhi        Delhi    Delhi    28.670       77.2
# 2456    2000-01-15  Maharashtra  Mumbai city   Mumbai    18.970       72.8
# 2472    2000-01-15   Tamil Nadu      Chennai  Chennai    13.086       80.3
# 2500    2000-02-15        Delhi        Delhi    Delhi    28.670       77.2
# 2524    2000-02-15  Maharashtra  Mumbai city   Mumbai    18.970       72.8
# ...            ...          ...          ...      ...       ...        ...
# 107766  2020-10-15  Maharashtra  Mumbai city   Mumbai    18.970       72.8
# 107768  2020-10-15  Maharashtra  Mumbai city   Mumbai    18.970       72.8
# 107774  2020-10-15  Maharashtra  Mumbai city   Mumbai    18.970       72.8
# 108250  2020-10-15   Tamil Nadu      Chennai  Chennai    13.086       80.3
# 108252  2020-10-15   Tamil Nadu      Chennai  Chennai    13.086       80.3
#
# ...

# %%
df.loc[df['price']>4000, 'market']
# Out:
# 12041       Delhi
# 12146       Delhi
# 64788      Mumbai
# 65895      Mumbai
# 67002      Mumbai
# 69855       Delhi
# 70963       Delhi
# 72073       Delhi
# 73182       Delhi
# 95813     Chennai
# 96917     Chennai
# 97994     Chennai
# 99075     Chennai
# 100162    Chennai
# 101229    Chennai
# 102294    Chennai
# 103339    Chennai
# 104386    Chennai
# 105430    Chennai
# 106477    Chennai
# 108250    Chennai
# Name: market, dtype: object

# %%
df.loc[lambda df: df['market'] == 'Chennai']
# Out:
#               date      admin1   admin2   market  latitude  longitude  \
# 61      1994-02-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 62      1994-02-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 63      1994-02-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 64      1994-02-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 105     1994-03-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# ...            ...         ...      ...      ...       ...        ...
# 131525  2021-07-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 131526  2021-07-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 131527  2021-07-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 131528  2021-07-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
# 131529  2021-07-15  Tamil Nadu  Chennai  Chennai    13.086       80.3
#
#                      category        commodity unit pricetype currency  \
# ...

# %%
df[(df['date'] > '2016-06-01') & (df['date'] < '2016-12-31')]
# Out:
#              date               admin1           admin2      market  latitude  \
# 55326  2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair    11.664
# 55327  2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair    11.664
# 55328  2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair    11.664
# 55329  2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair    11.664
# 55330  2016-06-15  Andaman and Nicobar  Andaman Islands  Port Blair    11.664
# ...           ...                  ...              ...         ...       ...
# 63084  2016-12-15          West Bengal          Kolkata     Kolkata    22.560
# 63085  2016-12-15          West Bengal          Kolkata     Kolkata    22.560
# 63086  2016-12-15          West Bengal          Kolkata     Kolkata    22.560
# 63087  2016-12-15          West Bengal          Kolkata     Kolkata    22.560
# 63088  2016-12-15          West Bengal          Kolkata     Kolkata    22.560
#
# ...

# %%
df[(df['date'] == '2000-01-15') | (df['date'] == '2021-01-15')]
# Out:
#               date       admin1          admin2     market  latitude  \
# 2422    2000-01-15        Assam          Kamrup   Guwahati     26.19
# 2423    2000-01-15        Assam          Kamrup   Guwahati     26.19
# 2424    2000-01-15        Assam          Kamrup   Guwahati     26.19
# 2425    2000-01-15        Bihar           Patna      Patna     25.60
# 2426    2000-01-15        Bihar           Patna      Patna     25.60
# ...            ...          ...             ...        ...       ...
# 115804  2021-01-15  West Bengal  West Midnapore  Kharagpur     22.34
# 115805  2021-01-15  West Bengal  West Midnapore  Kharagpur     22.34
# 115806  2021-01-15  West Bengal  West Midnapore  Kharagpur     22.34
# 115807  2021-01-15  West Bengal  West Midnapore  Kharagpur     22.34
# 115808  2021-01-15  West Bengal  West Midnapore  Kharagpur     22.34
#
#         longitude               category        commodity    unit pricetype  \
# ...
