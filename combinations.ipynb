# %%
import itertools
import pandas as pd

# %% [markdown]
# create 5 list of some values
# for example config = [RAM, hard] like 5 list
# all the combinations of rows
# final column result

# %%
friends = ['arun','parthi','amsa']
cricket = ['virat','dhoni','rohit']
tennis = ['federer','nadal','alcaraz']
chess = ['magnus','nepo','anand']
shuttle = ['sindhu','newal','lakshaya']

# %%
combo = []
for x in friends:
    for y in cricket:
        for z in tennis:
            for c in chess:
                for s in shuttle:
                    l = [x,y,z,c,s]
                    combo.append(l)
pd.DataFrame(combo,columns = ['friends','cricket','tennis','chess','shuttle'])
# Out:
#     friends cricket   tennis   chess   shuttle
# 0      arun   virat  federer  magnus    sindhu
# 1      arun   virat  federer  magnus     newal
# 2      arun   virat  federer  magnus  lakshaya
# 3      arun   virat  federer    nepo    sindhu
# 4      arun   virat  federer    nepo     newal
# ..      ...     ...      ...     ...       ...
# 238    amsa   rohit  alcaraz    nepo     newal
# 239    amsa   rohit  alcaraz    nepo  lakshaya
# 240    amsa   rohit  alcaraz   anand    sindhu
# 241    amsa   rohit  alcaraz   anand     newal
# 242    amsa   rohit  alcaraz   anand  lakshaya
#
# [243 rows x 5 columns]

# %%
a = list(itertools.combinations([friends,cricket,tennis,chess,shuttle],5))

# %%
a
# Out:
# [(['arun', 'parthi', 'amsa'],
#   ['virat', 'dhoni', 'rohit'],
#   ['federer', 'nadal', 'alcaraz'],
#   ['magnus', 'nepo', 'anand'],
#   ['sindhu', 'newal', 'lakshaya'])]

# %%
for i in a:
    print(i)
# Out:
# (['arun', 'parthi', 'amsa'], ['virat', 'dhoni', 'rohit'], ['federer', 'nadal', 'alcaraz'], ['magnus', 'nepo', 'anand'], ['sindhu', 'newal', 'lakshaya'])

# %%
combinations = list(itertools.product(friends, cricket, tennis, chess, shuttle))
# Out:
# arun	virat	federer	magnus	sindhu
# arun	virat	federer	magnus	newal
# arun	virat	federer	magnus	lakshaya
# arun	virat	federer	nepo	sindhu
# arun	virat	federer	nepo	newal
# arun	virat	federer	nepo	lakshaya
# arun	virat	federer	anand	sindhu
# arun	virat	federer	anand	newal
# arun	virat	federer	anand	lakshaya
# arun	virat	nadal	magnus	sindhu
# arun	virat	nadal	magnus	newal
# arun	virat	nadal	magnus	lakshaya
# arun	virat	nadal	nepo	sindhu
# arun	virat	nadal	nepo	newal
# arun	virat	nadal	nepo	lakshaya
# arun	virat	nadal	anand	sindhu
# arun	virat	nadal	anand	newal
# arun	virat	nadal	anand	lakshaya
# arun	virat	alcaraz	magnus	sindhu
# arun	virat	alcaraz	magnus	newal
# arun	virat	alcaraz	magnus	lakshaya
# arun	virat	alcaraz	nepo	sindhu
# arun	virat	alcaraz	nepo	newal
# arun	virat	alcaraz	nepo	lakshaya
# arun	virat	alcaraz	anand	sindhu
# arun	virat	alcaraz	anand	newal
# arun	virat	alcaraz	anand	lakshaya
# arun	dhoni	federer	magnus	sindhu
# arun	dhoni	federer	magnus	newal
# ...

# %%
df = pd.DataFrame(combinations)

# %%
df.columns = ['friends','cricket','tennis','chess','shuttle']

# %%
df
# Out:
#     friends cricket   tennis   chess   shuttle
# 0      arun   virat  federer  magnus    sindhu
# 1      arun   virat  federer  magnus     newal
# 2      arun   virat  federer  magnus  lakshaya
# 3      arun   virat  federer    nepo    sindhu
# 4      arun   virat  federer    nepo     newal
# ..      ...     ...      ...     ...       ...
# 238    amsa   rohit  alcaraz    nepo     newal
# 239    amsa   rohit  alcaraz    nepo  lakshaya
# 240    amsa   rohit  alcaraz   anand    sindhu
# 241    amsa   rohit  alcaraz   anand     newal
# 242    amsa   rohit  alcaraz   anand  lakshaya
#
# [243 rows x 5 columns]

# %%
combinations = list(itertools.product(friends, cricket, tennis, chess, shuttle))

# %% [markdown]
# total number of columns = 5
# number of categories in each column = 3

# %%
total_combinations = 3**5

# %%
total_combinations
# Out:
# 243

# %%
a = list(itertools.accumulate([1,2,3]))

# %%
a
# Out:
# [1, 3, 6]

# %%
chain = list(itertools.chain('abcdef'))

# %%
chain
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
combinations1 = list(itertools.combinations([friends, cricket, tennis, chess, shuttle],5))

# %%
combinations1
# Out:
# [(['arun', 'parthi', 'amsa'],
#   ['virat', 'dhoni', 'rohit'],
#   ['federer', 'nadal', 'alcaraz'],
#   ['magnus', 'nepo', 'anand'],
#   ['sindhu', 'newal', 'lakshaya'])]
