# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('optimised_food_price.csv')
df.head()
# Out:
#          date   admin1     admin2     market  latitude  longitude  \
# 0  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 1  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 2  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 3  1994-01-15    Delhi      Delhi      Delhi     28.67       77.2
# 4  1994-01-15  Gujarat  Ahmadabad  Ahmedabad     23.03       72.6
#
#              category      commodity unit pricetype currency  price  usdprice
# 0  cereals and tubers           Rice   KG    actual      INR    8.0      0.25
# 1  cereals and tubers          Wheat   KG    actual      INR    5.0      0.16
# 2  miscellaneous food          Sugar   KG    actual      INR   13.5      0.43
# 3        oil and fats  Oil (mustard)   KG    actual      INR   31.0      0.99
# 4  cereals and tubers           Rice   KG    actual      INR    6.8      0.22

# %%
df.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'unit', 'pricetype', 'currency', 'price',
#        'usdprice'],
#       dtype='object')

# %%
df1 = df[['date','market','category', 'commodity', 'unit','price']]

# %%
df_kg = df1.loc[df1['unit']=='KG']

# %%
df_kg.drop('unit',axis = 1, inplace = True)
# Out:
# C:\Users\U6049975\AppData\Local\Temp\ipykernel_8452\851164419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kg.drop('unit',axis = 1, inplace = True)

# %%
df_kg.loc[df_kg['price']==567.5]
# Out:
#               date     market            category    commodity  price
# 128660  2021-06-15  Cuddalore  miscellaneous food  Tea (black)  567.5

# %%
df_kg.to_excel('optimized_india_food_prices.xlsx',index = False)

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        print(f'{col}----{df[col].unique()}')
# Out:
# date----['1994-01-15' '1994-02-15' '1994-03-15' '1994-04-15' '1994-05-15'
#  '1994-06-15' '1994-07-15' '1994-08-15' '1994-09-15' '1994-10-15'
#  '1994-11-15' '1994-12-15' '1995-01-15' '1995-02-15' '1995-03-15'
#  '1995-04-15' '1995-05-15' '1995-06-15' '1995-07-15' '1995-08-15'
#  '1995-09-15' '1995-10-15' '1995-11-15' '1995-12-15' '1996-01-15'
#  '1996-02-15' '1996-03-15' '1996-04-15' '1996-05-15' '1996-06-15'
#  '1996-07-15' '1996-08-15' '1996-09-15' '1996-10-15' '1996-11-15'
#  '1996-12-15' '1997-01-15' '1997-02-15' '1997-03-15' '1997-04-15'
#  '1997-05-15' '1997-06-15' '1997-07-15' '1997-08-15' '1997-09-15'
#  '1997-10-15' '1997-11-15' '1997-12-15' '1998-01-15' '1998-02-15'
#  '1998-03-15' '1998-04-15' '1998-05-15' '1998-06-15' '1998-07-15'
#  '1998-08-15' '1998-09-15' '1998-10-15' '1998-11-15' '1998-12-15'
#  '1999-01-15' '1999-02-15' '1999-03-15' '1999-04-15' '1999-05-15'
#  '1999-06-15' '1999-07-15' '1999-08-15' '1999-09-15' '1999-10-15'
# ...

# %%
for col in df.loc[df['unit']=='100 KG']:
    df['price'] == df['price']/100

# %%
df.loc[df['unit']=='100 KG']
# Out:
#               date       admin1       admin2   market  latitude  longitude  \
# 2425    2000-01-15        Bihar        Patna    Patna    25.600       85.1
# 2427    2000-01-15        Bihar        Patna    Patna    25.600       85.1
# 2432    2000-01-15        Delhi        Delhi    Delhi    28.670       77.2
# 2434    2000-01-15        Delhi        Delhi    Delhi    28.670       77.2
# 2456    2000-01-15  Maharashtra  Mumbai city   Mumbai    18.970       72.8
# ...            ...          ...          ...      ...       ...        ...
# 107766  2020-10-15  Maharashtra  Mumbai city   Mumbai    18.970       72.8
# 107768  2020-10-15  Maharashtra  Mumbai city   Mumbai    18.970       72.8
# 107774  2020-10-15  Maharashtra  Mumbai city   Mumbai    18.970       72.8
# 108250  2020-10-15   Tamil Nadu      Chennai  Chennai    13.086       80.3
# 108252  2020-10-15   Tamil Nadu      Chennai  Chennai    13.086       80.3
#
# ...

# %%
if df['unit']== '100 KG':
